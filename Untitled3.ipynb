# %% [markdown]
# ## Задача 1
# Постройте график.
#
# Назовите график.
#
# Сделайте именование оси x и оси y.
#
# Сделайте выводы.
#
# ### 1.1. Скачать данные

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('kc_final.csv', encoding='Windows-1251')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(6, 6))
plt.hist(df['price'])
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Стоимость, млн')
plt.ylabel('Количество');

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(6, 8))
sns.histplot(df['sqft_living'], bins=20)
plt.title('Распределение квадратуры жилой')
plt.xlabel('Кв. метры жилые')
plt.ylabel('Количество');

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(6, 8))
sns.histplot(df['yr_built'], bins=30)
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество');

# %% [markdown]
# **Выводы:** Количество домов значительно выше до 1 млн. по стоимости, чем больше стоимость, тем меньше домов. Более 12 тысяч домов имеет площадь от 1000 до 2100 кв. метров. В каждым годом рост стоительства увеличивался. Были периоды спада, на которые могут влиять внешние факторы(экономические, политические).

# %% [markdown]
# ## Задача 2
# ### 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график.
#
# Сделайте выводы.

# %%
data = df['waterfront'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(data, autopct='%1.1f%%')
plt.legend(['Без вида', 'С видом']);
plt.title('Распределение домов от наличия вида на набережную');

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %%
def calcExplodes(data):
    exp = []
    k = 1
    for val in data.values:
        if val < data.values.sum() / 20:
            exp.append(0.3 * k)
            k += 1
        else:
            exp.append(0)
    return exp

# %%
data = df['floors'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(data, autopct='%1.2f%%', explode=calcExplodes(data))
plt.legend(data.index)
plt.title('Количество этажей');

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
data = df['condition'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(data, autopct='%1.2f%%', explode=calcExplodes(data))
plt.legend(data.index)
plt.title('Состояние домов');

# %% [markdown]
# ## Задача 3
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix = np.round(corr_matrix, 1)
corr_matrix[np.abs(corr_matrix) < 0.3] = 0
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')
plt.title("Матрица корреляции признаков");

# %% [markdown]
# Цена домов сильно зависит от жилой площади.

# %% [markdown]
# Зависимость цены от жилой площади:

# %%
sns.jointplot(x=df['sqft_living'], y=df['price'], kind='reg')

plt.xlabel("Жилая площадь, кв. м")
plt.ylabel("Цена дома, млн");

# %%
sns.boxplot(x=df['price'], y=df['floors'].astype('str'), whis=1.5);
plt.xlabel('Стоимость')
plt.ylabel('Этаж')
plt.title('Зависимость цены от этажности');

# %% [markdown]
# Наибольшую стоимость имеют дома с количеством этажей 2,5.

# %%
sns.boxplot(x=df['price'], y=df['view'].astype('str'), whis=1.5);
plt.xlabel('Стоимость')
plt.ylabel('Виды')
plt.title('Зависимость стоимости от вида');

# %% [markdown]
# Наибольшую стоимость имеют дома с оценкой вида 4.

# %%
sns.boxplot(x=df['price'], y=df['grade'].astype('str'), whis=1.5);
plt.xlabel('Стоимость')
plt.ylabel('Класс')
plt.title('Зависимость стоимости от класса дома');

# %% [markdown]
# Наибольшую стоимость имеют дома с оценкой класса 13.
